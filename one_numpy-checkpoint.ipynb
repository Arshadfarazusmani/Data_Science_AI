# %% [markdown]
# # Numpy

# %% [markdown]
# ## NumPy is a Python library that provides support for large multi-dimensional arrays and mathematical functions to operate on them efficiently.

# %%
import numpy as np

# %%
a=12
